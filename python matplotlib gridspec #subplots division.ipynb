# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import squarify
import itertools
from pylab import *
import matplotlib.gridspec as gridspec

# %%
gs = gridspec.GridSpec(2, 2)
ax = plt.subplot(gs[0, 0])
ax = plt.subplot(gs[1, 1])

# %%
gs = gridspec.GridSpec(2, 3,
                       width_ratios=[12, 2,1],
                       height_ratios=[1, 1]
                       )

ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])
ax3 = plt.subplot(gs[2])
ax4 = plt.subplot(gs[3])
ax5 = plt.subplot(gs[4])
ax6 = plt.subplot(gs[5])
#ax4 = plt.subplot(gs[3])

# %%
gs = gridspec.GridSpec(1, 2,
                       width_ratios=[12, 2] #if there are more than 2 columns only we need this
                       #height_ratios=[1, 1] #if there are more than 2 rows only we need this
                       )

ax1 = plt.subplot(gs[0])
ax1=plt.plot([10,20,30],[10,20,30])
plt.axis('off') #the outer boundary wotn be visisble
ax2 = plt.subplot(gs[1])
ax2=plt.plot([40,50],[40,50])
plt.axis('off')
plt.show(ax1,ax2)
#ax3 = plt.subplot(gs[2])
#ax4 = plt.subplot(gs[3])

# %%
gs = gridspec.GridSpec(1, 2,
                       width_ratios=[12, 2]
                       #height_ratios=[1, 1]
                       )

ax1 = plt.subplot(gs[0])
ax1=plt.plot([10,20,30],[10,20,30])
#plt.axis('off') #the outer boundary wotn be visisble
ax2 = plt.subplot(gs[1])
ax2=plt.plot([40,50],[40,50])
plt.axis('off')
#ax3 = plt.subplot(gs[2])
#ax4 = plt.subplot(gs[3])
# Out:
# (39.5, 50.5, 39.5, 50.5)

# %%
gs = gridspec.GridSpec(2, 2,
                       width_ratios=[2, 2],
                       height_ratios=[1, 1]
                       )

ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])
ax3 = plt.subplot(gs[2])
ax4 = plt.subplot(gs[3])

# %%
gs = gridspec.GridSpec(2,2,width_ratios=[ 15,1.5],height_ratios=[15, 2],wspace=0.0)
ax1 = plt.subplot(gs[0])
ax1 = plt.subplot(gs[1])
ax1 = plt.subplot(gs[2])
ax1 = plt.subplot(gs[3])
